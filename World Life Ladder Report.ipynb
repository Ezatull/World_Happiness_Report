# %% [markdown]
# ![](https://www.eudebates.tv/wp-content/uploads/2019/02/World-Happiness-Report.jpg)

# %% [markdown]
# # Introduction:

# %% [markdown]
# The World Happiness Report is a yearly publication that assesses and examines the happiness levels of populations across the globe. Beyond a mere ranking of nations by happiness, the report unfolds as an intricate narrative, delving into the reasons behind varying happiness levels worldwide. By envisioning happiness as a ladder, where the pinnacle signifies utmost joy and the base represents lesser contentment, the report allows us to comprehend the varying levels of happiness experienced in different regions.
#
# However, this report's scope transcends mere measurement; it morphs into a metaphorical detective story, seeking to unveil the factors underlying divergent happiness levels. These factors encompass economic indicators, life expectancy, freedom to make choices, and the presence of social support networks. Furthermore, the report chronicles the dynamics of change over time—alterations that may either elevate or diminish happiness. Governments and organizations can leverage this information to enhance the quality of life within their countries.
#
# Ultimately, the World Happiness Report is a profound exploration, not limited to statistical figures but deeply rooted in comprehending the human experience. It strives to fathom what brings smiles to people's faces across cultures and continents, channeling this insight to foster greater happiness in all corners of the world.

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
import pandas as pd

# %%
data=pd.read_csv('full_happy.csv')

# %%
print(data.head())
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support
# 0  Afghanistan  2008        3.724               7.350           0.451  \
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity
# 0                              50.5                         0.718       0.168  \
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   Life Ladder                       2199 non-null   float64
#  3   Log GDP per capita                2179 non-null   float64
#  4   Social support                    2186 non-null   float64
#  5   Healthy life expectancy at birth  2145 non-null   float64
#  6   Freedom to make life choices      2166 non-null   float64
#  7   Generosity                        2126 non-null   float64
#  8   Perceptions of corruption         2083 non-null   float64
#  9   Positive affect                   2175 non-null   float64
#  10  Negative affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
data.shape
# Out:
# (2199, 11)

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (1958, 11)

# %% [markdown]
# Pandas library is used to read a CSV file named 'full_happy.csv' into a DataFrame called 'data'. The CSV file contain information about various countries' well-being factors over multiple years. The DataFrame displays a snapshot of the data using the print(data.head()) command, showing the first few rows and columns.
#
# The DataFrame has 11 columns:
#
# Country name: Name of the country
# year: Year of data collection
# Life Ladder: A measure of life satisfaction or happiness
# Log GDP per capita: Logarithm of GDP per capita, indicating economic prosperity
# Social support: Level of social support within the country
# Healthy life expectancy at birth: Expected lifespan in good health at birth
# Freedom to make life choices: Degree of personal freedom in life decisions
# Generosity: Measure of generosity within the country
# Perceptions of corruption: Perception of corruption within the country
# Positive affect: Measure of positive emotional expression
# Negative affect: Measure of negative emotional expression
#
# The print(data.info()) statement provides an overview of the DataFrame's structure, including the data types of each column and the number of non-null values.
#
# The data.shape command is used to display the shape of the DataFrame, which shows the number of rows and columns.
#
# Subsequently, the data.dropna(inplace=True) function is called to remove rows with missing values. After performing this operation, the DataFrame's shape becomes (1958, 11), meaning there are now 1958 rows of data with complete information.
#
# In summary, the well-being data from a CSV file into a DataFrame, displays a preview of the data, provides information about the DataFrame's structure, manipulates the data by removing rows with missing values, and displays the resulting shape of the DataFrame.

# %% [markdown]
# # Exploratory Analysis & Visualization

# %% [markdown]
# Performing exploratory data analysis (EDA) on the 'data' DataFrame using the Seaborn and Matplotlib libraries.

# %%
numeric_stats = data.describe()
numeric_stats
# Out:
#               year  Life Ladder  Log GDP per capita  Social support
# count  1958.000000  1958.000000         1958.000000     1958.000000  \
# mean   2014.308478     5.458662            9.344036        0.808119
# std       4.640344     1.141020            1.158002        0.123490
# min    2005.000000     2.179000            5.527000        0.290000
# 25%    2011.000000     4.609000            8.442500        0.739000
# 50%    2014.000000     5.391000            9.494000        0.834000
# 75%    2018.000000     6.274500           10.303000        0.906000
# max    2022.000000     7.971000           11.664000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices
# count                       1958.000000                   1958.000000  \
# mean                          63.156228                      0.745453
# std                            7.068698                      0.140502
# min                            6.720000                      0.258000
# ...

# %% [markdown]
# Descriptive Statistics:
# Numeric statistics are calculated using the describe() function and stored in the numeric_stats variable.
# These statistics provide information about the central tendency and spread of each numeric column in the DataFrame.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numerical_columns = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numerical_columns.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of Numerical Variables',fontsize=16)
plt.show()

# %% [markdown]
# Correlation Heatmap:
# The correlation matrix between numeric columns is calculated using the .corr() method on the numerical_columns.
# A heatmap of the correlation matrix is created using Seaborn's heatmap() function.
# The heatmap visualizes the relationships between numeric variables, with color intensity indicating the strength and direction of the correlation.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.hist(data['Log GDP per capita'], bins=20, color='blue', alpha=0.7)
plt.xlabel('Log GDP per capita')
plt.ylabel('Frequency')
plt.title('Distribution of Log GDP per capita')
plt.show()

# %% [markdown]
# Histogram:
# A histogram is plotted using Matplotlib to visualize the distribution of the 'Log GDP per capita' column.
# The x-axis represents the 'Log GDP per capita' values, and the y-axis represents the frequency of those values in the dataset.
# The Log GDP per capita range from 0 to nearly 12 however, most of its values are around 9 to 11.

# %%
plt.figure(figsize=(12,10))
plt.scatter(data['Life Ladder'], data['Freedom to make life choices'], alpha=0.5)
plt.xlabel('Life Ladder')
plt.ylabel('Freedom to make life choices')
plt.title('Relationship between Life Ladder and Freedom to make life choices')
plt.show()

# %%
data.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))  
plt.scatter(data['Log GDP per capita'], data['Freedom to make life choices'], alpha=0.7)
plt.title('Scatter Plot of Log GDP per Capita vs Freedom',fontsize=16)
plt.xlabel('Log GDP per Capita',fontsize=14)
plt.ylabel('Freedom to make life choices',fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['Log GDP per capita'], data['Healthy life expectancy at birth'], alpha=0.7)
plt.title('Log GDP per Capita vs Healthy Life Expectancy')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Healthy Life Expectancy')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['Social support'], data['Positive affect'], alpha=0.7)
plt.title('Social Support vs Positive Affect')
plt.xlabel('Social Support')
plt.ylabel('Positive Affect')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['Generosity'], data['Perceptions of corruption'], alpha=0.7)
plt.title('Generosity vs Perceptions of Corruption')
plt.xlabel('Generosity')
plt.ylabel('Perceptions of Corruption')
plt.grid(True)
plt.show()

# %% [markdown]
# Scatter Plots:
# Multiple scatter plots are created to explore relationships between different pairs of numeric variables.
#
# The first scatter plot shows the relationship between 'Life ladder' and 'Freedom to make life choices'. This scatter shows positive relation between freedom to make life choices and life ladder.
#
# The second scatter plot shows the relationship between 'Log GDP per capita' and 'Healthy life expectancy at birth'. These two parameters also seems to have positive relationship
#
# The third scatter plot shows the relationship between 'Social support' and 'Positive affect'.
#
# The fourth scatter plot shows the relationship between 'Generosity' and 'Perceptions of corruption'.
# Each scatter plot visualizes the correlation or relationship between two specific numeric variables, helping to identify potential patterns or trends in the data.
#
# A series of individual scatter plots are created, each exploring the relationship between a numeric variable and another numeric variable.
# 'Log GDP per capita' vs. 'Freedom to make life choices'
# 'Log GDP per capita' vs. 'Healthy life expectancy at birth'
# 'Social support' vs. 'Positive affect'
# 'Generosity' vs. 'Perceptions of corruption'
#
# Overall, various data visualization techniques used to explore relationships and distributions within the 'data' DataFrame.

# %% [markdown]
# # Q & A

# %% [markdown]
# Average Life Ladder:

# %%
Life_Ladder = data['Life Ladder'].mean()
Life_Ladder
# Out:
# 5.458662410623085

# %% [markdown]
# The "Life Ladder" column represents a measure of life satisfaction or happiness. By calculating the mean of this column, you're essentially finding the average happiness score across all countries and years present in the dataset. The computed mean value of approximately 5.46 suggests that, on average, the sampled countries tend to report a moderate level of life satisfaction.

# %% [markdown]
# Country with the Highest GDP:

# %%
highest_gdp_country = data.loc[data['Log GDP per capita'].idxmax(), 'Country name']
highest_gdp_country
# Out:
# 'Luxembourg'

# %% [markdown]
# The "Log GDP per capita" serves as an indicator of a country's economic prosperity. By identifying the country with the highest value in this column, you're pinpointing the nation that has the highest economic output per person. In this case, Luxembourg is recognized as having the highest per capita GDP, indicating its strong economic standing relative to other countries.

# %% [markdown]
# Distribution of Freedom Scores:

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Freedom to make life choices'], bins=15, color='green', alpha=0.7)
plt.xlabel('Freedom to make life choices')
plt.ylabel('Frequency')
plt.title('Distribution of Freedom to make life choices')
plt.show()

# %% [markdown]
# Visualizing the distribution of "Freedom to make life choices" scores through a histogram allows you to understand how this well-being factor is spread across the dataset. The histogram's x-axis showcases different ranges of freedom scores, while the y-axis displays the frequency of countries falling within those score ranges. This visualization range from 0.2 to nearly 1, however frequent values are between 0.7 to 0.9 meaning if a country hvae values within this interval it has similar freedom to most of the countries around the world.

# %% [markdown]
# Countires with lowest life expectancy:

# %%
Lowest_life_expectancy=data.sort_values('Healthy life expectancy at birth',
                                        ascending=True).drop_duplicates(subset='Country name').head(5)

# %%
Lowest_life_expectancy
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita
# 766                      Haiti  2006        3.754               7.973  \
# 2182                  Zimbabwe  2006        3.826               7.460
# 344   Central African Republic  2007        4.160               6.946
# 1118                   Lesotho  2011        4.898               7.785
# 610                   Eswatini  2011        4.867               8.902
#
#       Social support  Healthy life expectancy at birth
# 766            0.694                              6.72  \
# 2182           0.822                             40.40
# 344            0.532                             41.48
# 1118           0.824                             41.52
# 610            0.837                             42.50
#
#       Freedom to make life choices  Generosity  Perceptions of corruption
# 766                          0.449       0.359                      0.854  \
# ...

# %% [markdown]
# Sorting the data by "Healthy life expectancy at birth" in ascending order allows you to identify the countries with the lowest values in terms of expected lifespan in good health. This subset of countries, including Haiti, Zimbabwe, Central African Republic, Lesotho, and Eswatini, presents a group facing significant challenges in terms of health and well-being.

# %% [markdown]
# Afghanistan Life Ladder data

# %%
afghanistan_data = data[data['Country name'] == 'Afghanistan']
afghanistan_data
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support
# 0   Afghanistan  2008        3.724               7.350           0.451  \
# 1   Afghanistan  2009        4.402               7.509           0.552
# 2   Afghanistan  2010        4.758               7.614           0.539
# 3   Afghanistan  2011        3.832               7.581           0.521
# 4   Afghanistan  2012        3.783               7.661           0.521
# 5   Afghanistan  2013        3.572               7.680           0.484
# 6   Afghanistan  2014        3.131               7.671           0.526
# 7   Afghanistan  2015        3.983               7.654           0.529
# 8   Afghanistan  2016        4.220               7.650           0.559
# 9   Afghanistan  2017        2.662               7.648           0.491
# 10  Afghanistan  2018        2.694               7.631           0.508
# 11  Afghanistan  2019        2.375               7.640           0.420
# ...

# %%
data
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support
# 0     Afghanistan  2008        3.724               7.350           0.451  \
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018        3.616               7.783           0.775
# 2195     Zimbabwe  2019        2.694               7.698           0.759
# 2196     Zimbabwe  2020        3.160               7.596           0.717
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(afghanistan_data['year'], afghanistan_data['Freedom to make life choices'], color='blue')
plt.title('Freedom to Make Life Choices in Afghanistan (by Year)',fontsize=16)
plt.xlabel('Year',fontsize=14)
plt.ylabel('Freedom',fontsize=14)
plt.grid(True)
plt.show()

# %%
afghanistan_data = data[data['Country name'] == 'Afghanistan']
plt.figure(figsize=(10, 6)) 
plt.plot(afghanistan_data['year'].values, afghanistan_data['Generosity'].values, marker='o', color='tab:blue')
plt.xlabel('Year',fontsize=14)
plt.ylabel('Generosity',fontsize=14)
plt.title('Generosity Over Years in Afghanistan',fontsize=16)

plt.grid()
plt.show()

# %% [markdown]
# Extracting data specific to Afghanistan from the larger dataset allows you to focus on the happiness scores of this particular country over different years. By observing the changes in the "Life Ladder" scores year by year, you can potentially identify trends or fluctuations in Afghanistan's reported life satisfaction.
#
# Plotting Freedom in Afghanistan by Year:
# Creating a bar plot to visualize "Freedom to make life choices" in Afghanistan across different years enables you to track how this specific aspect of well-being has evolved over time in the country. The x-axis illustrates the years, while the y-axis represents the reported levels of freedom. This visualization show freedom in Afghanistan decreasing.
#
# Regrettably, each positive indicator of happiness within my country is undergoing a distressing decline. This unsettling trend has propelled our nation to become recognized as one of the most perilous and precarious places in the world.

# %% [markdown]
# # Summary

# %% [markdown]
# This analysis of the World Happiness Report delved into the intricate relationship between diverse variables and the concept of happiness, often quantified through the "life ladder" metric. The investigation unearthed substantial correlations, particularly between GDP, life expectancy, freedom, and happiness scores.
#
# Our findings illuminated that countries with higher GDP tend to exhibit elevated life expectancy and greater happiness scores. This implies that economic prosperity is intertwined with well-being, suggesting that nations with limited economic resources may struggle to attain higher levels of happiness.
#
# Furthermore, the study underscored that nations fostering greater levels of freedom tend to manifest not only elevated GDP but also increased happiness scores. This underscores the pivotal role of personal freedom in nurturing well-being and overall life satisfaction on a global scale.
#
# Regrettably, in my homeland, Afghanistan, the parameters associated with evaluating the life ladder or happiness are undergoing a distressing decline due to ongoing conflict and instability. As each positive marker of happiness diminishes, Afghanistan finds itself ensnared in the vortex of complex challenges, positioning the nation among the world's most precarious and dangerous places.
#
# Future Directions:
# To further enrich this analysis:
#
# Scrutinize how these indicators have evolved over successive years, pinpointing potential trends or transformations.
# Continue monitoring the life ladder scores to gauge the effectiveness of government policies and interventions, shedding light on changes in global circumstances.
# Resources:
#
# World Happiness Report Website: Link
#
# Data Visualization Best Practices: Link
